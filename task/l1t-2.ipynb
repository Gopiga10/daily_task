# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  
mean_value = np.mean(data)
variance_value = np.var(data)
std_dev_value = np.std(data)
skewness_value = stats.skew(data)
kurtosis_value = stats.kurtosis(data)
plt.figure(figsize=(12, 6), facecolor="#FAFAFA")  
sns.histplot(data, bins=30, kde=True, color="#4A90E2", alpha=0.7, edgecolor="black")
plt.axvline(mean_value, color="red", linestyle="dashed", linewidth=2, label=f"Mean = {mean_value:.2f}")
plt.axvline(mean_value + std_dev_value, color="darkgreen", linestyle="dashed", linewidth=2, label="Mean + 1σ")
plt.axvline(mean_value - std_dev_value, color="darkgreen", linestyle="dashed", linewidth=2, label="Mean - 1σ")
sns.kdeplot(data, color="black", linewidth=2.5, label="Density Curve")
plt.title(" Data Distribution with Summary Statistics", fontsize=16, fontweight="bold", color="darkblue")
plt.xlabel("Data Values", fontsize=12, fontweight="bold")
plt.ylabel("Frequency", fontsize=12, fontweight="bold")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)

summary_df = pd.DataFrame({
    "Statistic": ["Mean", "Variance", "Standard Deviation", "Skewness", "Kurtosis"],
    "Value": [mean_value, variance_value, std_dev_value, skewness_value, kurtosis_value]
})
print(summary_df)

plt.show()
# Out:
#             Statistic       Value
# 0                Mean   50.289981
# 1            Variance  215.528623
# 2  Standard Deviation   14.680893
# 3            Skewness    0.116801
# 4            Kurtosis    0.066206
