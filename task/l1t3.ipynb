# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
y_true = np.random.normal(loc=50, scale=10, size=100) 
y_pred = y_true + np.random.normal(loc=0, scale=5, size=100)  
bias = np.mean(y_pred - y_true)
mse = np.mean((y_pred - y_true) ** 2)
rmse = np.sqrt(mse)
standard_error = np.std(y_pred - y_true) / np.sqrt(len(y_true))
plt.figure(figsize=(10, 5), facecolor="#FAFAFA")
plt.scatter(y_true, y_pred, color="blue", alpha=0.6, label="Predicted vs Actual")
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], color="red", linestyle="dashed", linewidth=2, label="Ideal Fit")
plt.xlabel("Actual Values (y_true)", fontsize=12, fontweight="bold")
plt.ylabel("Predicted Values (y_pred)", fontsize=12, fontweight="bold")
plt.title(" Error Metrics Visualization", fontsize=14, fontweight="bold", color="darkblue")
plt.legend()
plt.grid(alpha=0.3)

error_table = pd.DataFrame({
    "Metric": ["Bias", "Mean Squared Error (MSE)", "Root Mean Squared Error (RMSE)", "Standard Error"],
    "Value": [bias, mse, rmse, standard_error]
})

fig, ax = plt.subplots(figsize=(6, 2))
ax.axis("tight")
ax.axis("off")
table = ax.table(cellText=error_table.values, colLabels=error_table.columns, cellLoc="center", loc="center")
table.set_fontsize(10)
plt.show()
